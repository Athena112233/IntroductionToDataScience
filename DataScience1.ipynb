# %% [markdown]
# # introduction to data
# Data Science is inter-disciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from many structural and unstructured data.
#
# Related Fields: computer science, statistics, cognitive science, etc.
#
# Basic: Data Cleaning/Manipulating (finding basic statistic and make sense of it) <br>
# Intermediate: Insight on Data (finding correlations) <br>
# Advance: Machine Learning Algorithm <br>

# %%
#import libraries
import pandas as pd #data analysis, organizational, manipulation library
import numpy as np #math library
import matplotlib.pyplot as plt #plotting library - data visualization
import seaborn as sns #plotting library - data visalizations

# %%
#import data files
happy2020 = pd.read_csv('data/happiness2020.csv')

# %%
#step1: examine the data file
#things to look for: size, column names, data type
happy2020
# Out:
#                  Country name            Regional indicator  Ladder score  \
# 0                     Finland                Western Europe        7.8087
# 1                     Denmark                Western Europe        7.6456
# 2                 Switzerland                Western Europe        7.5599
# 3                     Iceland                Western Europe        7.5045
# 4                      Norway                Western Europe        7.4880
# 5                 Netherlands                Western Europe        7.4489
# 6                      Sweden                Western Europe        7.3535
# 7                 New Zealand         North America and ANZ        7.2996
# 8                     Austria                Western Europe        7.2942
# 9                  Luxembourg                Western Europe        7.2375
# 10                     Canada         North America and ANZ        7.2321
# 11                  Australia         North America and ANZ        7.2228
# ...

# %%
#how to dispaly partial of the dataframe
happy2020.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
#how many rows x columns I have aka dimension
#return a tuple
happy2020.shape
# Out:
# (153, 20)

# %%
#how to get specific columns
#only look at country names
happy2020['Country name'] #series
# Out:
# 0                       Finland
# 1                       Denmark
# 2                   Switzerland
# 3                       Iceland
# 4                        Norway
# 5                   Netherlands
# 6                        Sweden
# 7                   New Zealand
# 8                       Austria
# 9                    Luxembourg
# 10                       Canada
# 11                    Australia
# 12               United Kingdom
# 13                       Israel
# 14                   Costa Rica
# 15                      Ireland
# 16                      Germany
# 17                United States
# 18               Czech Republic
# 19                      Belgium
# 20         United Arab Emirates
# 21                        Malta
# 22                       France
# 23                       Mexico
# 24     Taiwan Province of China
# 25                      Uruguay
# 26                 Saudi Arabia
# 27                        Spain
# 28                    Guatemala
# ...

# %%
happy2020[['Country name']] #dataframe
# Out:
#                  Country name
# 0                     Finland
# 1                     Denmark
# 2                 Switzerland
# 3                     Iceland
# 4                      Norway
# 5                 Netherlands
# 6                      Sweden
# 7                 New Zealand
# 8                     Austria
# 9                  Luxembourg
# 10                     Canada
# 11                  Australia
# 12             United Kingdom
# 13                     Israel
# 14                 Costa Rica
# 15                    Ireland
# 16                    Germany
# 17              United States
# 18             Czech Republic
# 19                    Belgium
# 20       United Arab Emirates
# 21                      Malta
# 22                     France
# 23                     Mexico
# 24   Taiwan Province of China
# 25                    Uruguay
# 26               Saudi Arabia
# 27                      Spain
# 28                  Guatemala
# 29                      Italy
# ...

# %%
#how to get specific value
#index 3, iceland, get regional indicator
#iloc --> location by index
happy2020.iloc[3]['Regional indicator'] #on dataframe
# Out:
# 'Western Europe'

# %%
happy2020['Regional indicator'].iloc[3] #on series
# Out:
# 'Western Europe'

# %%
#how to get rows by specific values
#loc --> find location
#pandas use True/False selector --> if row is classified as false, it's gonna get filtered out
#if row is classified as true, keep that row

happy2020.loc[happy2020['Country name'] == 'China']
# Out:
#    Country name Regional indicator  Ladder score  \
# 93        China          East Asia        5.1239
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 93                        0.025902      5.174667      5.073133
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 93               9.688568        0.798761                69.289192
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 93                      0.898518   -0.181426                   0.753971
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 93                  1.972317                          0.990533
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 93                      1.132081                               0.867249
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 93                                    0.601605                  0.079021
#
# ...

# %%
#find all the countries that's in North America
happy2020.loc[happy2020['Regional indicator'] == 'North America and ANZ']
# Out:
#      Country name     Regional indicator  Ladder score  \
# 7     New Zealand  North America and ANZ        7.2996
# 10         Canada  North America and ANZ        7.2321
# 11      Australia  North America and ANZ        7.2228
# 17  United States  North America and ANZ        6.9396
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 7                         0.039465      7.376953      7.222248
# 10                        0.040405      7.311295      7.152905
# 11                        0.041841      7.304808      7.140791
# 17                        0.047316      7.032340      6.846860
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 7               10.500943        0.949119                73.202629
# 10              10.692369        0.927177                73.601601
# 11              10.720596        0.944855                73.604538
# 17              10.925769        0.914219                68.299500
#
# ...

# %%
#locate with multiple statements
happy2020.loc[(happy2020['Country name'] == 'China') | (happy2020['Country name'] == 'United States')]
# Out:
#      Country name     Regional indicator  Ladder score  \
# 17  United States  North America and ANZ        6.9396
# 93          China              East Asia        5.1239
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 17                        0.047316      7.032340      6.846860
# 93                        0.025902      5.174667      5.073133
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 17              10.925769        0.914219                68.299500
# 93               9.688568        0.798761                69.289192
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 17                      0.842620    0.149892                   0.699715
# 93                      0.898518   -0.181426                   0.753971
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 17                  1.972317                          1.373987
# ...

# %%
#numeric
happy2020.loc[happy2020['Ladder score'] >= 7]
# Out:
#       Country name            Regional indicator  Ladder score  \
# 0          Finland                Western Europe        7.8087
# 1          Denmark                Western Europe        7.6456
# 2      Switzerland                Western Europe        7.5599
# 3          Iceland                Western Europe        7.5045
# 4           Norway                Western Europe        7.4880
# 5      Netherlands                Western Europe        7.4489
# 6           Sweden                Western Europe        7.3535
# 7      New Zealand         North America and ANZ        7.2996
# 8          Austria                Western Europe        7.2942
# 9       Luxembourg                Western Europe        7.2375
# 10          Canada         North America and ANZ        7.2321
# 11       Australia         North America and ANZ        7.2228
# 12  United Kingdom                Western Europe        7.1645
# 13          Israel  Middle East and North Africa        7.1286
# ...

# %% [markdown]
# ## Homework ##
#
# 1. Find all data for any country with life expectancy above 60 (dataframe)
# 2. Find all data for any country with ladder score between 5 and 7 (dataframe)
# 3. Find the country name of any country with life expectancy less than less than 58 (series)

# %% [markdown]
# ## Lesson 2 Data Aggregation + Data Combination ###

# %%
#collapse data
happy2020.groupby('Regional indicator').min()
# Out:
#                                    Country name  Ladder score  \
# Regional indicator
# Central and Eastern Europe              Albania        4.8827
# Commonwealth of Independent States      Armenia        4.5607
# East Asia                                 China        5.1239
# Latin America and Caribbean           Argentina        3.7208
# Middle East and North Africa            Algeria        3.5274
# North America and ANZ                 Australia        6.9396
# South Asia                          Afghanistan        2.5669
# Southeast Asia                         Cambodia        4.3080
# Sub-Saharan Africa                        Benin        2.8166
# Western Europe                          Austria        5.5150
#
#                                     Standard error of ladder score  \
# Regional indicator
# Central and Eastern Europe                                0.034838
# Commonwealth of Independent States                        0.029380
# ...

# %%
happy2020.pivot_table(index = ['Regional indicator', 'Country name'], values = ['Ladder score', 'Logged GDP per capita'], aggfunc = 'mean')
# Out:
#                                                            Ladder score  \
# Regional indicator                 Country name
# Central and Eastern Europe         Albania                       4.8827
#                                    Bosnia and Herzegovina        5.6741
#                                    Bulgaria                      5.1015
#                                    Croatia                       5.5047
#                                    Czech Republic                6.9109
#                                    Estonia                       6.0218
#                                    Hungary                       6.0004
#                                    Kosovo                        6.3252
#                                    Latvia                        5.9500
#                                    Lithuania                     6.2155
#                                    Macedonia                     5.1598
# ...

# %%
#merge, join, concat https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
happy2015 = pd.read_csv('data/happiness2015.csv') #happiness score
happy2016 = pd.read_csv('data/happiness2016.csv') #happiness score
happy2017 = pd.read_csv('data/happiness2017.csv') #happiness score
happy2018 = pd.read_csv('data/happiness2018.csv') #score
happy2019 = pd.read_csv('data/happiness2019.csv') #score
happy2020 = pd.read_csv('data/happiness2020.csv') #ladder score

# %%
happy2015 = happy2015.rename(columns  = {'Happiness Score': 'Score', 'Happiness Rank': 'Rank', })[['Country', 'Region', 'Score']]
happy2016 = happy2016.rename(columns  = {'Happiness Score': 'Score'})[['Country', 'Region', 'Score']]
happy2017 = happy2017.rename(columns  = {'Happiness.Score': 'Score'})[['Country', 'Score']]
happy2018 = happy2018.rename(columns  = {'Country or region': 'Country'})[['Country', 'Score']]
happy2019 = happy2019.rename(columns  = {'Country or region': 'Country'})[['Country', 'Score']]
happy2020 = happy2020.rename(columns = {'Ladder score': 'Score', 'Country name': 'Country', 'Regional indicator': 'Region'})[['Country', 'Region', 'Score']]

# %%
happy2015.shape #158 countries
happy2016.shape #157 countries
happy2017.shape #155 countries
happy2018.shape #156 countries
happy2019.shape #156 countries
happy2020.shape #153 countries
# Out:
# (153, 3)

# %%
lst2020 = {'Taiwan Province of China': 'Taiwan', 'Hong Kong S.A.R. of China': 'Hong Kong', 'South Sudan': 'Sudan'}

# %%
#column cleaning
happy2020['Country'] = happy2020['Country'].replace(lst2020)

# %%
temp = pd.merge(happy2015, happy2020, right_on = 'Country', left_on = 'Country', suffixes=('2015', '2020')) #previous merge 147
temp
# Out:
#                       Country                       Region2015  Score2015  \
# 0                 Switzerland                   Western Europe      7.587
# 1                     Iceland                   Western Europe      7.561
# 2                     Denmark                   Western Europe      7.527
# 3                      Norway                   Western Europe      7.522
# 4                      Canada                    North America      7.427
# 5                     Finland                   Western Europe      7.406
# 6                 Netherlands                   Western Europe      7.378
# 7                      Sweden                   Western Europe      7.364
# 8                 New Zealand        Australia and New Zealand      7.286
# 9                   Australia        Australia and New Zealand      7.284
# 10                     Israel  Middle East and Northern Africa      7.278
# 11                 Costa Rica      Latin America and Caribbean      7.226
# ...

# %%
top20 = temp.iloc[:20]
top20
# Out:
#                  Country                       Region2015  Score2015  \
# 0            Switzerland                   Western Europe      7.587
# 1                Iceland                   Western Europe      7.561
# 2                Denmark                   Western Europe      7.527
# 3                 Norway                   Western Europe      7.522
# 4                 Canada                    North America      7.427
# 5                Finland                   Western Europe      7.406
# 6            Netherlands                   Western Europe      7.378
# 7                 Sweden                   Western Europe      7.364
# 8            New Zealand        Australia and New Zealand      7.286
# 9              Australia        Australia and New Zealand      7.284
# 10                Israel  Middle East and Northern Africa      7.278
# 11            Costa Rica      Latin America and Caribbean      7.226
# 12               Austria                   Western Europe      7.200
# ...

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(6, 10))
sns.set_color_codes("pastel")
sns.barplot(x = 'Score2015', y = 'Country', data = top20)

# %%
lst1 = list(temp['Country'])
lst2 = list(happy2015['Country'])

# %%
list(set(lst2) - set(lst1))
# Out:
# ['Bhutan',
#  'Somaliland region',
#  'Qatar',
#  'Djibouti',
#  'Syria',
#  'Oman',
#  'Suriname',
#  'Angola']

# %%
happy2020.loc[happy2020['Country'].str.contains('Tai')]
# Out:
#    Country     Region   Score
# 24  Taiwan  East Asia  6.4554

# %%
happy2020.loc[happy2020['Country'].str.contains('Hong')]
# Out:
#       Country     Region   Score
# 77  Hong Kong  East Asia  5.5104

# %%
happy2020.loc[happy2020['Country'].str.contains('Sud')]
# Out:
#     Country              Region   Score
# 151   Sudan  Sub-Saharan Africa  2.8166

# %%
happy2020.loc[happy2020['Country'].str.contains('tar')]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Score]
# Index: []

# %% [markdown]
# ### HW2
#
# 1. Create a pivot table that is based on region on 2015, find the mean score and GDP
# 2. Rename the following columns: all happiness rank should be renamed to rank, rename all GDP per capita to GDP to capita, rename life expectancy to life expectancy

# %% [markdown]
# ## Lesson 3: Geopandas ##

# %%
#horizontal bar plot
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(6, 30))
sns.set_color_codes("pastel")
sns.barplot(x = 'Ladder score', y = 'Country name', data = happy2020)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-dce901963407> in <module>
#       3 f, ax = plt.subplots(figsize=(6, 30))
#       4 sns.set_color_codes("pastel")
# ----> 5 sns.barplot(x = 'Ladder score', y = 'Country name', data = happy2020)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ...

# %%
f
