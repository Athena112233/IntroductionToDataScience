# %%
# import nesesary libaries
import pandas as pd # data analysis, origizational, manipulation libary
import numpy as np #math libary
import matplotlib.pyplot as plt #plotting libary- data visualization
import seaborn as sns #plotting libary- data visualization
# Out:
# C:\Users\athen\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#import data files
happy2015 = pd.read_csv('data/happiness2015.csv')
happy2016 = pd.read_csv('data/happiness2016.csv')
happy2017 = pd.read_csv('data/happiness2017.csv')
happy2018 = pd.read_csv('data/happiness2018.csv')
happy2019 = pd.read_csv('data/happiness2019.csv')
happy2020 = pd.read_csv('data/happiness2020.csv')

# %%
happy2020
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %%
# display partial
happy2020.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
#demensions
happy2020.shape# return tuple
# Out:
# (153, 20)

# %%
# how to get specific colums
# only look at country names
happy2020['Country name']# displays seies
# Out:
# 0                       Finland
# 1                       Denmark
# 2                   Switzerland
# 3                       Iceland
# 4                        Norway
#                  ...
# 148    Central African Republic
# 149                      Rwanda
# 150                    Zimbabwe
# 151                 South Sudan
# 152                 Afghanistan
# Name: Country name, Length: 153, dtype: object

# %%
happy2020[['Country name']]#displays dataframe
# Out:
#                  Country name
# 0                     Finland
# 1                     Denmark
# 2                 Switzerland
# 3                     Iceland
# 4                      Norway
# ..                        ...
# 148  Central African Republic
# 149                    Rwanda
# 150                  Zimbabwe
# 151               South Sudan
# 152               Afghanistan
#
# [153 rows x 1 columns]

# %%
# acsess vaulue individualy
#index 3, icland, get regional inddecator
# iloc --> location get index
happy2020.iloc[3]['Regional indicator'] # on dataframe
# Out:
# 'Western Europe'

# %%
happy2020['Regional indicator'].iloc[3] # on series
# Out:
# 'Western Europe'

# %%
# get specific row 
# loc -> find location
#paddas give true/fasle selector -. if false it is going to be filtered out
#if row is clasivied true keep that row

happy2020.loc[happy2020['Country name'] =='China']
# Out:
#    Country name Regional indicator  Ladder score  \
# 93        China          East Asia        5.1239
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 93                        0.025902      5.174667      5.073133
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 93               9.688568        0.798761                69.289192
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 93                      0.898518   -0.181426                   0.753971
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 93                  1.972317                          0.990533
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 93                      1.132081                               0.867249
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 93                                    0.601605                  0.079021
#
# ...

# %%
#find all countries that are in North America
happy2020.loc[happy2020['Regional indicator']=='North America and ANZ']
# Out:
#      Country name     Regional indicator  Ladder score  \
# 7     New Zealand  North America and ANZ        7.2996
# 10         Canada  North America and ANZ        7.2321
# 11      Australia  North America and ANZ        7.2228
# 17  United States  North America and ANZ        6.9396
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 7                         0.039465      7.376953      7.222248
# 10                        0.040405      7.311295      7.152905
# 11                        0.041841      7.304808      7.140791
# 17                        0.047316      7.032340      6.846860
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 7               10.500943        0.949119                73.202629
# 10              10.692369        0.927177                73.601601
# 11              10.720596        0.944855                73.604538
# 17              10.925769        0.914219                68.299500
#
# ...

# %%
#locate with multiple statments
happy2020.loc[(happy2020['Country name']=='China')|(happy2020['Country name']=='United States')]
# Out:
#      Country name     Regional indicator  Ladder score  \
# 17  United States  North America and ANZ        6.9396
# 93          China              East Asia        5.1239
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 17                        0.047316      7.032340      6.846860
# 93                        0.025902      5.174667      5.073133
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 17              10.925769        0.914219                68.299500
# 93               9.688568        0.798761                69.289192
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 17                      0.842620    0.149892                   0.699715
# 93                      0.898518   -0.181426                   0.753971
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 17                  1.972317                          1.373987
# ...

# %%
#numeric select
happy2020.loc[happy2020['Ladder score']>=7]
# Out:
#       Country name            Regional indicator  Ladder score  \
# 0          Finland                Western Europe        7.8087
# 1          Denmark                Western Europe        7.6456
# 2      Switzerland                Western Europe        7.5599
# 3          Iceland                Western Europe        7.5045
# 4           Norway                Western Europe        7.4880
# 5      Netherlands                Western Europe        7.4489
# 6           Sweden                Western Europe        7.3535
# 7      New Zealand         North America and ANZ        7.2996
# 8          Austria                Western Europe        7.2942
# 9       Luxembourg                Western Europe        7.2375
# 10          Canada         North America and ANZ        7.2321
# 11       Australia         North America and ANZ        7.2228
# 12  United Kingdom                Western Europe        7.1645
# 13          Israel  Middle East and North Africa        7.1286
# ...

# %% [markdown]
# Homwork
#
# 1. find all data for all countries with life expectancy above 60(dataframe)
# 2. find all data for all countries with ladder score between 5 and 7(dataframe)
# 3. find country name of any country with life expectancy less than 58(series)

# %%
#ques 1.

happy2020.loc[happy2020['Healthy life expectancy']>=60]
# Out:
#     Country name            Regional indicator  Ladder score  \
# 0        Finland                Western Europe        7.8087
# 1        Denmark                Western Europe        7.6456
# 2    Switzerland                Western Europe        7.5599
# 3        Iceland                Western Europe        7.5045
# 4         Norway                Western Europe        7.4880
# ..           ...                           ...           ...
# 127      Tunisia  Middle East and North Africa        4.3922
# 129    Sri Lanka                    South Asia        4.3270
# 137        Egypt  Middle East and North Africa        4.1514
# 143        India                    South Asia        3.5733
# 149       Rwanda            Sub-Saharan Africa        3.3123
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %%
#ques 2


happy2020.loc[(happy2020['Ladder score']>=5) & (happy2020['Ladder score']<= 7)]
# Out:
#             Country name            Regional indicator  Ladder score  \
# 17         United States         North America and ANZ        6.9396
# 18        Czech Republic    Central and Eastern Europe        6.9109
# 19               Belgium                Western Europe        6.8635
# 20  United Arab Emirates  Middle East and North Africa        6.7908
# 21                 Malta                Western Europe        6.7728
# ..                   ...                           ...           ...
# 95              Bulgaria    Central and Eastern Europe        5.1015
# 96               Morocco  Middle East and North Africa        5.0948
# 97              Cameroon            Sub-Saharan Africa        5.0849
# 98             Venezuela   Latin America and Caribbean        5.0532
# 99               Algeria  Middle East and North Africa        5.0051
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 17                        0.047316      7.032340      6.846860
# ...

# %%
#ques 3

happy2020['Country name'].loc[happy2020['Healthy life expectancy']<=58]
# Out:
# 84                  Ivory Coast
# 85                        Benin
# 87          Congo (Brazzaville)
# 90                        Ghana
# 97                     Cameroon
# 101                      Guinea
# 102                       Niger
# 108                South Africa
# 111                Burkina Faso
# 112                      Gambia
# 113                        Mali
# 114                     Nigeria
# 119                  Mozambique
# 121                     Namibia
# 123                     Liberia
# 125                      Uganda
# 126                        Chad
# 128                  Mauritania
# 130            Congo (Kinshasa)
# 131                   Swaziland
# 133                     Comoros
# 134                        Togo
# 138                Sierra Leone
# 139                     Burundi
# 140                      Zambia
# 141                       Haiti
# 142                     Lesotho
# 144                      Malawi
# 145                       Yemen
# ...

# %%
# agregate data - combining data using summary
# ex. finding total hapines per reigion

# %%
# collaps data using groupby
happy2020.groupby('Regional indicator').mean()
# Out:
#                                     Ladder score  \
# Regional indicator
# Central and Eastern Europe              5.883818
# Commonwealth of Independent States      5.358342
# East Asia                               5.714850
# Latin America and Caribbean             5.981786
# Middle East and North Africa            5.227159
# North America and ANZ                   7.173525
# South Asia                              4.475443
# Southeast Asia                          5.383367
# Sub-Saharan Africa                      4.383495
# Western Europe                          6.899219
#
#                                     Standard error of ladder score  \
# Regional indicator
# Central and Eastern Europe                                0.043896
# Commonwealth of Independent States                        0.042306
# East Asia                                                 0.039475
# Latin America and Caribbean                               0.063247
# ...

# %%
# colapse data using pivot table

happy2020.pivot_table(index = ['Regional indicator'], values =['Ladder score','Ladder score in Dystopia','Logged GDP per capita'], aggfunc = 'mean')
# Out:
#                                     Ladder score  Ladder score in Dystopia  \
# Regional indicator
# Central and Eastern Europe              5.883818                  1.972317
# Commonwealth of Independent States      5.358342                  1.972317
# East Asia                               5.714850                  1.972317
# Latin America and Caribbean             5.981786                  1.972317
# Middle East and North Africa            5.227159                  1.972317
# North America and ANZ                   7.173525                  1.972317
# South Asia                              4.475443                  1.972317
# Southeast Asia                          5.383367                  1.972317
# Sub-Saharan Africa                      4.383495                  1.972317
# Western Europe                          6.899219                  1.972317
#
#                                     Logged GDP per capita
# Regional indicator
# ...

# %%
#merge, join, concat https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
happy2015 = pd.read_csv('data/happiness2015.csv')# hapiness score
happy2016 = pd.read_csv('data/happiness2016.csv')# hapiness score
happy2017 = pd.read_csv('data/happiness2017.csv')#hapiness.score
happy2018 = pd.read_csv('data/happiness2018.csv')#score
happy2019 = pd.read_csv('data/happiness2019.csv')#score
happy2020 = pd.read_csv('data/happiness2020.csv')#ladder score

# %%
happy2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# ## Homework 7.25.2020
#
# 1. Create a pivot table that is based on region on 2015, find the mean score and GDP

# %%
happy2015 =  happy2015.rename(columns = {'Happiness Score' : 'Score', 'Economy (GDP per Capita)' : 'GDP'})[['Country', 'Region', 'Score']]
happy2016 =  happy2016.rename(columns = {'Happiness Score' : 'Score', 'Economy (GDP per Capita)' : 'GDP'})[['Country', 'Region', 'Score']]
happy2017 =  happy2017.rename(columns = {'Happiness.Score' : 'Score', 'Economy..GDP.per.Capita.' : 'GDP'})[['Country', 'Score']]
happy2018 =  happy2018.rename(columns = {'GDP per Capita' : 'GDP', 'Country or region':'Country'})[['Country', 'Score']]
happy2019 =  happy2018.rename(columns = { 'Country or region':'Country'})[['Country', 'Score']]
happy2020 =  happy2020.rename(columns = {'Ladder score' : 'Score','Economy..GDP.per.Capita.' : 'GDP', 'Regional indicator':'Region', 'Country name' :'Country' })[['Country', 'Region', 'Score']]

# %%
happy2015.pivot_table(index = ['Region'], values =['Score'], aggfunc = 'mean')
# Out:
#                                     Score
# Region
# Australia and New Zealand        7.285000
# Central and Eastern Europe       5.332931
# Eastern Asia                     5.626167
# Latin America and Caribbean      6.144682
# Middle East and Northern Africa  5.406900
# North America                    7.273000
# Southeastern Asia                5.317444
# Southern Asia                    4.580857
# Sub-Saharan Africa               4.202800
# Western Europe                   6.689619

# %%
happy2019
# Out:
#                       Country  Score
# 0                     Finland  7.632
# 1                      Norway  7.594
# 2                     Denmark  7.555
# 3                     Iceland  7.495
# 4                 Switzerland  7.487
# ..                        ...    ...
# 151                     Yemen  3.355
# 152                  Tanzania  3.303
# 153               South Sudan  3.254
# 154  Central African Republic  3.083
# 155                   Burundi  2.905
#
# [156 rows x 2 columns]

# %%
happy2015.shape#158 countries
happy2016.shape#157 countries
happy2017.shape#155 countries
happy2018.shape#156 countries
happy2019.shape#156 countriess\
happy2020.shape#153 countries
# Out:
# (153, 3)

# %%
lst2020 = {'Taiwan Province of China' : 'Taiwan', 'Hong Kong S.A.R. of China' : 'Hong Kong', 'South Sudan':'Sudan'}

# %%
#Colum cleeaning
happy2020['Country'] = happy2020['Country'].replace(lst2020)

# %%
temp = pd.merge(happy2015, happy2020, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2020'))
temp
# Out:
#          Country          Region2015  Score2015             Region2020  \
# 0    Switzerland      Western Europe      7.587         Western Europe
# 1        Iceland      Western Europe      7.561         Western Europe
# 2        Denmark      Western Europe      7.527         Western Europe
# 3         Norway      Western Europe      7.522         Western Europe
# 4         Canada       North America      7.427  North America and ANZ
# ..           ...                 ...        ...                    ...
# 145  Afghanistan       Southern Asia      3.575             South Asia
# 146       Rwanda  Sub-Saharan Africa      3.465     Sub-Saharan Africa
# 147        Benin  Sub-Saharan Africa      3.340     Sub-Saharan Africa
# 148      Burundi  Sub-Saharan Africa      2.905     Sub-Saharan Africa
# 149         Togo  Sub-Saharan Africa      2.839     Sub-Saharan Africa
#
#      Score2020
# 0       7.5599
# 1       7.5045
# 2       7.6456
# 3       7.4880
# 4       7.2321
# ..         ...
# ...

# %%
top20 = temp.iloc[:20]

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize = (6,10))
sns.set_color_codes("pastel")
sns.barplot(x = 'Score2015', y = 'Country', data= top20)

# %% [markdown]
# ## Homework 🍣🍥
#
# 1: Mergre (2015, 2016), (2015, 2017), (2015, 2019),(2015,2020)
# 2: find which country is in 2015 and not in merge table and fix

# %%
# o = original
#f = fixed

#p1 2015,2016
m15_16o = pd.merge(happy2015, happy2016, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2016'))
m15_16o
# Out:
#          Country                       Region2015  Score2015  \
# 0    Switzerland                   Western Europe      7.587
# 1        Iceland                   Western Europe      7.561
# 2        Denmark                   Western Europe      7.527
# 3         Norway                   Western Europe      7.522
# 4         Canada                    North America      7.427
# ..           ...                              ...        ...
# 146       Rwanda               Sub-Saharan Africa      3.465
# 147        Benin               Sub-Saharan Africa      3.340
# 148        Syria  Middle East and Northern Africa      3.006
# 149      Burundi               Sub-Saharan Africa      2.905
# 150         Togo               Sub-Saharan Africa      2.839
#
#                           Region2016  Score2016
# 0                     Western Europe      7.509
# 1                     Western Europe      7.501
# 2                     Western Europe      7.526
# ...

# %%
lst1 = list(m15_16o['Country'])
lst2 = list(happy2015['Country'])
list(set(lst2) - set(lst1))
# Out:
# ['Swaziland',
#  'Lesotho',
#  'Oman',
#  'Djibouti',
#  'Central African Republic',
#  'Somaliland region',
#  'Mozambique']

# %%
happy2016.loc[happy2016['Country'].str.contains('Moz')]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Score]
# Index: []

# %%
happy2016.loc[happy2016['Country'].str.contains('Afri')]
# Out:
#           Country              Region  Score
# 115  South Africa  Sub-Saharan Africa  4.459

# %%
happy2016.loc[happy2016['Country'].str.contains('O')]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Score]
# Index: []

# %%
happy2016.loc[happy2016['Country'].str.contains('Leso')]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Score]
# Index: []

# %%
happy2016.loc[happy2016['Country'].str.contains('Dj')]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Score]
# Index: []

# %%
happy2016.loc[happy2016['Country'].str.contains('Swa')]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Score]
# Index: []

# %%
happy2016.loc[happy2016['Country'].str.contains('Som')]  #found match capitalization dif
# Out:
#               Country              Region  Score
# 75            Somalia  Sub-Saharan Africa  5.440
# 96  Somaliland Region  Sub-Saharan Africa  5.057

# %%
lst2016c = {'Somaliland Region': 'Somaliland region'}
happy2016['Country'] = happy2016['Country'].replace(lst2016c)

m15_16f = pd.merge(happy2015, happy2016, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2016'))
lst1 = list(m15_16f['Country'])
lst2 = list(happy2015['Country'])
list(set(lst2) - set(lst1))
# Out:
# ['Swaziland',
#  'Lesotho',
#  'Oman',
#  'Djibouti',
#  'Central African Republic',
#  'Mozambique']

# %% [markdown]
# # 🎇🎇🎇🎇🎇🧨

# %%
#p2 2015,2017
m15_17o = pd.merge(happy2015, happy2017, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2017'))
m15_17o
# Out:
#          Country                           Region  Score2015  Score2017
# 0    Switzerland                   Western Europe      7.587      7.494
# 1        Iceland                   Western Europe      7.561      7.504
# 2        Denmark                   Western Europe      7.527      7.522
# 3         Norway                   Western Europe      7.522      7.537
# 4         Canada                    North America      7.427      7.316
# ..           ...                              ...        ...        ...
# 144       Rwanda               Sub-Saharan Africa      3.465      3.471
# 145        Benin               Sub-Saharan Africa      3.340      3.657
# 146        Syria  Middle East and Northern Africa      3.006      3.462
# 147      Burundi               Sub-Saharan Africa      2.905      2.905
# 148         Togo               Sub-Saharan Africa      2.839      3.495
#
# [149 rows x 4 columns]

# %%
lst1 = list(m15_17o['Country'])
lst2 = list(happy2015['Country'])
list(set(lst2) - set(lst1))
# Out:
# ['Laos',
#  'Swaziland',
#  'Oman',
#  'Comoros',
#  'Djibouti',
#  'Somaliland region',
#  'Suriname',
#  'Taiwan',
#  'Hong Kong']

# %%
happy2017.loc[happy2017['Country'].str.contains('Suri')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2017.loc[happy2017['Country'].str.contains('Com')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2017.loc[happy2017['Country'].str.contains('Tai')]  #match found name dif
# Out:
#                      Country  Score
# 32  Taiwan Province of China  6.422

# %%
happy2017.loc[happy2017['Country'].str.contains('Om')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2017.loc[happy2017['Country'].str.contains('Lao')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2017.loc[happy2017['Country'].str.contains('Hong')]  #match found name dif
# Out:
#                     Country  Score
# 70  Hong Kong S.A.R., China  5.472

# %%
happy2017.loc[happy2017['Country'].str.contains('Swaz')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2017.loc[happy2017['Country'].str.contains('Som')]
# Out:
#     Country  Score
# 92  Somalia  5.151

# %%
happy2017.loc[happy2017['Country'].str.contains('Dj')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
lst2017c = {'Taiwan Province of China': 'Taiwan','Hong Kong S.A.R., China':'Hong Kong'}
happy2017['Country'] = happy2017['Country'].replace(lst2017c)

m15_17f = pd.merge(happy2015, happy2017, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2017'))
lst1 = list(m15_17f['Country'])
lst2 = list(happy2015['Country'])
list(set(lst2) - set(lst1))
# Out:
# ['Laos',
#  'Swaziland',
#  'Oman',
#  'Comoros',
#  'Djibouti',
#  'Somaliland region',
#  'Suriname']

# %% [markdown]
# # 🎇🎇🎇🎇🎇🧨

# %%
#p2 2015,2018
m15_18o = pd.merge(happy2015, happy2018, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2018'))
m15_18o
# Out:
#          Country                           Region  Score2015  Score2018
# 0    Switzerland                   Western Europe      7.587      7.487
# 1        Iceland                   Western Europe      7.561      7.495
# 2        Denmark                   Western Europe      7.527      7.555
# 3         Norway                   Western Europe      7.522      7.594
# 4         Canada                    North America      7.427      7.328
# ..           ...                              ...        ...        ...
# 145       Rwanda               Sub-Saharan Africa      3.465      3.408
# 146        Benin               Sub-Saharan Africa      3.340      4.141
# 147        Syria  Middle East and Northern Africa      3.006      3.462
# 148      Burundi               Sub-Saharan Africa      2.905      2.905
# 149         Togo               Sub-Saharan Africa      2.839      3.999
#
# [150 rows x 4 columns]

# %%
lst1 = list(m15_18o['Country'])
lst2 = list(happy2015['Country'])
list(set(lst2) - set(lst1))
# Out:
# ['Swaziland',
#  'Oman',
#  'Comoros',
#  'Djibouti',
#  'Somaliland region',
#  'Suriname',
#  'Trinidad and Tobago',
#  'North Cyprus']

# %%
happy2018.loc[happy2018['Country'].str.contains('Suri')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2018.loc[happy2018['Country'].str.contains('Com')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2018.loc[happy2018['Country'].str.contains('O')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2018.loc[happy2018['Country'].str.contains('Tri')]  #match '&' instead of 'and'
# Out:
#               Country  Score
# 37  Trinidad & Tobago  6.192

# %%
happy2018.loc[happy2018['Country'].str.contains('Dj')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2018.loc[happy2018['Country'].str.contains('Swaz')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2018.loc[happy2018['Country'].str.contains('Som')]
# Out:
#     Country  Score
# 97  Somalia  4.982

# %%
happy2018.loc[happy2018['Country'].str.contains('Cy')]   # match 'Northern' instead of 'North'
# Out:
#             Country  Score
# 57  Northern Cyprus  5.835
# 60           Cyprus  5.762

# %%
lst2018c = {'Trinidad & Tobago': 'Trinidad and Tobago','Northern Cyprus':'North Cyprus'}
happy2018['Country'] = happy2018['Country'].replace(lst2018c)

m15_18f = pd.merge(happy2015, happy2018, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2018'))
lst1 = list(m15_18f['Country'])
lst2 = list(happy2015['Country'])
list(set(lst2) - set(lst1))
# Out:
# ['Swaziland', 'Oman', 'Comoros', 'Djibouti', 'Somaliland region', 'Suriname']

# %% [markdown]
# # 🎇🎇🎇🎇🎇🧨

# %%
#p3 2015,2019
m15_19o = pd.merge(happy2015, happy2019, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2019'))
m15_19o
# Out:
#          Country                           Region  Score2015  Score2019
# 0    Switzerland                   Western Europe      7.587      7.487
# 1        Iceland                   Western Europe      7.561      7.495
# 2        Denmark                   Western Europe      7.527      7.555
# 3         Norway                   Western Europe      7.522      7.594
# 4         Canada                    North America      7.427      7.328
# ..           ...                              ...        ...        ...
# 145       Rwanda               Sub-Saharan Africa      3.465      3.408
# 146        Benin               Sub-Saharan Africa      3.340      4.141
# 147        Syria  Middle East and Northern Africa      3.006      3.462
# 148      Burundi               Sub-Saharan Africa      2.905      2.905
# 149         Togo               Sub-Saharan Africa      2.839      3.999
#
# [150 rows x 4 columns]

# %%
lst1 = list(m15_19o['Country'])
lst2 = list(happy2015['Country'])
list(set(lst2) - set(lst1))
# Out:
# ['Swaziland',
#  'Oman',
#  'Comoros',
#  'Djibouti',
#  'Somaliland region',
#  'Suriname',
#  'Trinidad and Tobago',
#  'North Cyprus']

# %%
happy2019.loc[happy2019['Country'].str.contains('Sur')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2019.loc[happy2019['Country'].str.contains('Com')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2019.loc[happy2019['Country'].str.contains('O')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2019.loc[happy2019['Country'].str.contains('Tri')] #match '&' instead of 'and'
# Out:
#               Country  Score
# 37  Trinidad & Tobago  6.192

# %%
happy2019.loc[happy2019['Country'].str.contains('Dj')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2019.loc[happy2019['Country'].str.contains('Swaz')]
# Out:
# Empty DataFrame
# Columns: [Country, Score]
# Index: []

# %%
happy2019.loc[happy2019['Country'].str.contains('Som')]
# Out:
#     Country  Score
# 97  Somalia  4.982

# %%
happy2019.loc[happy2019['Country'].str.contains('Cy')]# match 'Northern' instead of 'North'
# Out:
#             Country  Score
# 57  Northern Cyprus  5.835
# 60           Cyprus  5.762

# %%
lst2019c = {'Trinidad & Tobago': 'Trinidad and Tobago','Northern Cyprus':'North Cyprus'}
happy2019['Country'] = happy2019['Country'].replace(lst2019c)

m15_19f = pd.merge(happy2015, happy2019, right_on = 'Country', left_on = 'Country', suffixes = ('2015', '2019'))
lst1 = list(m15_19f['Country'])
lst2 = list(happy2015['Country'])
list(set(lst2) - set(lst1))
# Out:
# ['Swaziland', 'Oman', 'Comoros', 'Djibouti', 'Somaliland region', 'Suriname']

# %% [markdown]
# # 🎇🎇🎇🎇🎇🧨

# %%
#p3 2015,2020
m15_20f = temp

# %% [markdown]
# # 🎇🎆🎇🧨🎇🎆🎇🧨

# %% [markdown]
# ## Standardizations
# Measured on difrent scale
# economy Gdp

# %%
m15_16_17 =pd.merge(m15_16f[["Region2015","Country","Score2015","Score2016"]], m15_17f[["Country","Score2017"]], right_on = 'Country', left_on = 'Country')
m15_16_17
# Out:
#                           Region2015      Country  Score2015  Score2016  \
# 0                     Western Europe  Switzerland      7.587      7.509
# 1                     Western Europe      Iceland      7.561      7.501
# 2                     Western Europe      Denmark      7.527      7.526
# 3                     Western Europe       Norway      7.522      7.498
# 4                      North America       Canada      7.427      7.404
# ..                               ...          ...        ...        ...
# 143               Sub-Saharan Africa       Rwanda      3.465      3.515
# 144               Sub-Saharan Africa        Benin      3.340      3.484
# 145  Middle East and Northern Africa        Syria      3.006      3.069
# 146               Sub-Saharan Africa      Burundi      2.905      2.905
# 147               Sub-Saharan Africa         Togo      2.839      3.303
#
#      Score2017
# 0        7.494
# 1        7.504
# 2        7.522
# 3        7.537
# 4        7.316
# ...

# %%
m15_16_17_18 = pd.merge(m15_16_17, m15_18f[["Country","Score2018"]], right_on = 'Country', left_on = 'Country')
m15_16_17_18
# Out:
#                           Region2015      Country  Score2015  Score2016  \
# 0                     Western Europe  Switzerland      7.587      7.509
# 1                     Western Europe      Iceland      7.561      7.501
# 2                     Western Europe      Denmark      7.527      7.526
# 3                     Western Europe       Norway      7.522      7.498
# 4                      North America       Canada      7.427      7.404
# ..                               ...          ...        ...        ...
# 143               Sub-Saharan Africa       Rwanda      3.465      3.515
# 144               Sub-Saharan Africa        Benin      3.340      3.484
# 145  Middle East and Northern Africa        Syria      3.006      3.069
# 146               Sub-Saharan Africa      Burundi      2.905      2.905
# 147               Sub-Saharan Africa         Togo      2.839      3.303
#
#      Score2017  Score2018
# 0        7.494      7.487
# 1        7.504      7.495
# ...

# %%
def standard(r,avrg,variance):
    return(r-av)/variance

# %% [markdown]
# # ✨✨✨✨✨
# ## Homework
# - Merge all data sets
# - Edabit recursion problem 1

# %%
m15_16_17_18_19 = pd.merge(m15_16_17_18, m15_19f[["Country","Score2019"]], right_on = 'Country', left_on = 'Country')
m15_16_17_18_19
# Out:
#                           Region2015      Country  Score2015  Score2016  \
# 0                     Western Europe  Switzerland      7.587      7.509
# 1                     Western Europe      Iceland      7.561      7.501
# 2                     Western Europe      Denmark      7.527      7.526
# 3                     Western Europe       Norway      7.522      7.498
# 4                      North America       Canada      7.427      7.404
# ..                               ...          ...        ...        ...
# 143               Sub-Saharan Africa       Rwanda      3.465      3.515
# 144               Sub-Saharan Africa        Benin      3.340      3.484
# 145  Middle East and Northern Africa        Syria      3.006      3.069
# 146               Sub-Saharan Africa      Burundi      2.905      2.905
# 147               Sub-Saharan Africa         Togo      2.839      3.303
#
#      Score2017  Score2018  Score2019
# 0        7.494      7.487      7.487
# ...

# %%
m_all = pd.merge(m15_16_17_18_19, m15_20f[["Country","Score2020"]], right_on = 'Country', left_on = 'Country')
m_all
# Out:
#              Region2015      Country  Score2015  Score2016  Score2017  \
# 0        Western Europe  Switzerland      7.587      7.509      7.494
# 1        Western Europe      Iceland      7.561      7.501      7.504
# 2        Western Europe      Denmark      7.527      7.526      7.522
# 3        Western Europe       Norway      7.522      7.498      7.537
# 4         North America       Canada      7.427      7.404      7.316
# ..                  ...          ...        ...        ...        ...
# 139       Southern Asia  Afghanistan      3.575      3.360      3.794
# 140  Sub-Saharan Africa       Rwanda      3.465      3.515      3.471
# 141  Sub-Saharan Africa        Benin      3.340      3.484      3.657
# 142  Sub-Saharan Africa      Burundi      2.905      2.905      2.905
# 143  Sub-Saharan Africa         Togo      2.839      3.303      3.495
#
#      Score2018  Score2019  Score2020
# 0        7.487      7.487     7.5599
# 1        7.495      7.495     7.5045
# ...

# %% [markdown]
# # 🎇🎇🎇🎇🎇🧨

# %%
data = m_all.loc[m_all['Country'] == 'Switzerland'].drop(columns = ['Region2015', 'Country']).iloc[0]
data
# Out:
# Score2015    7.5870
# Score2016    7.5090
# Score2017    7.4940
# Score2018    7.4870
# Score2019    7.4870
# Score2020    7.5599
# Name: 0, dtype: float64

# %%
data2 = m_all.loc[m_all['Country'] == 'Finland'].drop(columns = ['Region2015', 'Country']).iloc[0]
data2
# Out:
# Score2015    7.4060
# Score2016    7.4130
# Score2017    7.4690
# Score2018    7.6320
# Score2019    7.6320
# Score2020    7.8087
# Name: 5, dtype: float64

# %%
fig, ax = plt.subplots()
ax.plot(data.index, data.values)
ax.plot(data2.index, data2.values)

# %%
data.plot()
data2.plot()

# %%
data3 = m_all.pivot_table(index = 'Region2015', aggfunc = 'mean').transpose()
data3
# Out:
# Region2015  Australia and New Zealand  Central and Eastern Europe  \
# Score2015                      7.2850                    5.332931
# Score2016                      7.3235                    5.370690
# Score2017                      7.2990                    5.409931
# Score2018                      7.2980                    5.463966
# Score2019                      7.2980                    5.463966
# Score2020                      7.2612                    5.666379
#
# Region2015  Eastern Asia  Latin America and Caribbean  \
# Score2015       5.626167                     6.138762
# Score2016       5.624167                     6.056095
# Score2017       5.646667                     5.957905
# Score2018       5.672000                     5.949857
# Score2019       5.672000                     5.949857
# Score2020       5.714850                     5.981786
#
# Region2015  Middle East and Northern Africa  North America  Southeastern Asia  \
# ...

# %%
fig, ax1 = plt.subplots(figsize = (10, 10))
ax1.plot(data3)
fig.title = "Happiness Change in Each Region from 2015-2020"
ax.legend(data3.columns)
